# %% [markdown]
# <a href="https://colab.research.google.com/github/jwiggins281/GATechAnalytics_Practicum/blob/main/Practicum_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

amzSales = pd.read_csv('/content/amz_sales.csv')
amzSales['Date'] = pd.to_datetime(amzSales['Date'])
amzSales.sort_values(by='Date',ascending=True,inplace=True)
amzSales.reset_index(inplace=True)
amzSales = amzSales.loc[:,~amzSales.columns.isin(['index'])]



amzInv = pd.read_csv('/content/amz_inv.csv')
amzInv['Date'] = pd.to_datetime(amzInv['Date'])
amzInv.sort_values(by='Date',ascending=True,inplace=True)
amzInv.reset_index(inplace=True)
amzInv = amzInv.loc[:,~amzInv.columns.isin(['index'])]


masterProd = pd.read_csv('/content/mat_plant_table.csv')
masterProd
# Out:
#      Material_ID  Plant ABC_INDICATOR  STD_COST_USD              DIVISION  \
# 0        2081948   1920             C      0.019600  Outdoor & Recreation
# 1        2081948   1930             C      0.019600  Outdoor & Recreation
# 2        2081948   1960             C      0.019600  Outdoor & Recreation
# 3        2160473   1930             C      0.015854  Outdoor & Recreation
# 4        2155792   1920             C      0.242906  Outdoor & Recreation
# ...          ...    ...           ...           ...                   ...
# 1884  2000035530   1930             E      0.094778  Outdoor & Recreation
# 1885     2160944   1259             D      0.052026  Outdoor & Recreation
# 1886     2160944   1920             D      0.052026  Outdoor & Recreation
# 1887     2160944   1930             D      0.052026  Outdoor & Recreation
# 1888     2160944   1960             D      0.052026  Outdoor & Recreation
#
#      BUSINESS_UNIT          PRODUCT_CATEGORY        PRODUCT_FAMILY  \
# ...

# %%
masterProd[masterProd.Material_ID=='2081948']
# Out:
#   Material_ID  Plant ABC_INDICATOR  STD_COST_USD              DIVISION  \
# 0     2081948   1920             C        0.0196  Outdoor & Recreation
# 1     2081948   1930             C        0.0196  Outdoor & Recreation
# 2     2081948   1960             C        0.0196  Outdoor & Recreation
#
#   BUSINESS_UNIT PRODUCT_CATEGORY PRODUCT_FAMILY PRODUCT_LINE  \
# 0      Beverage          Thermal            Sip     Snapseal
# 1      Beverage          Thermal            Sip     Snapseal
# 2      Beverage          Thermal            Sip     Snapseal
#
#               MATERIAL_DESCRIPTION    BRAND XYZ_IND
# 0  COUTURE HURON 16OZ WHITE MARBLE  CONTIGO       Z
# 1  COUTURE HURON 16OZ WHITE MARBLE  CONTIGO       Y
# 2  COUTURE HURON 16OZ WHITE MARBLE  CONTIGO       Z
